# %%
"""                                       ASSIGNMENT

1) Who developed python programing language?
Answer) Guido van Rossum



2) Which type of programming does python support?
Answer) python is a multi paradigm programming language.
 Object oriented programming and structured programming are fully supported and many
of their features support functional programming and aspect oriented programming(including meta programming and meta objects).
It is a high level interperated programming language, supporting object-oriented, structured, and fuctional programming.



3) Is python case sensitive when dealing with identifiers?
Answer) Yes



4) What is correct extension of the python file?
Answer) .py


5) Is python code compiled or interpreted?
Answer) Python code is interpreted


6) Name a few block of code used to define in  python language?
Answer) a = 33
        b = 33
        if b > a:
           print("b is greater than a")
         elif a== b:
            print(" a and b are equal")
            
            
            
7) State the character used to give single line comments in python?            
Answer) #



8) Mention functions which can helo us to find the version of python?
Answer) Using python_version() function.
Using Python-V command
Using sys.version method



9) Python support the creation of anonymous function at runtime ,using a construct called?
Answer)lambda



10) What does pip stand for python?
Answer) PIP - pip install packages

The standard package manager for python is pip . It allows us to install and manage packages
that are not part of the python standard library.



11) Mention few built in functions in python ?
Answer) bytes(). ,callable(). ,chr(). ,classmethod(). ,all(). , abs().



12) What is the maximum possible length of an identifier in python ?   
Answer) 79 characters


13) What are the benifit of using python ?
Answer) a) Large developer community
b) Extensive libraries
c) Very concise syntex
d) Portability
e)Wide range of use cases
f) Interpreted language
g) Open source and free
h) Portability
i)IOT opportunity
j) Object Oriented
k) Used in various domains like data science, web development, computer graphics etc


14) Hoe is memory managed in python?
Answer) Memory management in python involves a private heap containing all python objects
and data structure. The management of this private heap is ensured internally by the python memory manager.



15) How  to install python on windows and set path variables?
Answer) Step 1) Select version of python to install
Step 2) Download python executable installer.
Step 3) Run executable installer.
Step 4) Verify python was installed on windows.
Step 5) Verify pip was installed.
Step 6) Add python path to environment variables.
Step 7) Install virtualnv.


16) Is indentation required in python?
Answer) Yes                                                                              """
