# %%
"""                   
                         [ ASSIGNMENT 13 FEB]
1] Why we have to use the exception class while creating a custom exception?

answer] In python we have the ability to creat our own exception classes. The construction of custom exception class can 
enrich our class design . A custom error class could logs errors,inspect an object. It is up to us what the exception class
does , although a custom class will not usually do a great deal more than display a message

# %%
"""
2] Write a python program to print python exception hierrchy.

# %%
import inspect
print(' the class hierarchy for built in exception is:')
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls,indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls , indent + 3)
classtree(Exception)
# Out:
#  the class hierarchy for built in exception is:
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... itimer_error
# ...... herror
# ...... gaierror
# ...... SSLError
# ......... SSLCertVerificationError
# ......... SSLZeroReturnError
# ......... SSLWantWriteError
# ......... SSLWantReadError
# ...

# %%
"""
3] What errors are defined in the arthmetic error class ? explain any two with an example.

answer] Arthmetic error types in python includes:
        1] over flow error - An overflow error exception is raised when an arthemetic operation exceeds the limit to be represented.
        2] zero division error - occur when divided by 0
        3] floating point error

# %%
arthmetic = 4/0                            # zero division error
print(arthmetic)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 arthmetic = 4/0
#       2 print(arthmetic)
#
# ZeroDivisionError: division by zero

# %%
j = 5.0
try:                                            # over flow error
    for i in range(1,1000):
        j = j**i
        print(j)
except OverflowError as e:
    print('over flow error happened')
    print(f"{e} , {e.__class__}")
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# over flow error happened
# (34, 'Numerical result out of range') , <class 'OverflowError'>

# %%
a = .2
b = .1                           # floating point error
a+b
# Out:
# 0.30000000000000004

# %%
"""
4] Why LookupError class is used? Explain with an example key error and index error.

answer] LookupError is the base class for errors raised when something cannot be found.The base class for the exceptions
that are raised when a key or index used on a mapping or sequence is invalid.
          Containers like lists and dictionaries will generate errors if you try to access items in them that do not exist
          , for lists this type of errors is called an indexerror; for dictionaries, it is called a keyerror.

# %%
test_list = [ 1,2,3,4]                  # index error
print(test_list[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [1], line 2
#       1 test_list = [ 1,2,3,4]
# ----> 2 print(test_list[4])
#
# IndexError: list index out of range

# %%
"""
5] Explain import error. What is module not found error?

answer] This error generally occurs when a class cannot be imported due to one of the following reasons:
1) The imported class is in a circular dependency.
2] The imported class is unavilable or was not created.
3] The imported class name is misspelled.
4] The imported class from a module is misplaced.
5] The imported class is unavilable in python library.

  AS the name implies , moduleNotFound error occurs when we try to access or use a module that can not be found.
  Their are few reasons why a module not be found:
1] we donot have the module we tried importing installed on our computer
2] we spelled a module incorrectly
3] we use an incorrect casting for a module
4] we are importing a module using a wrong path

# %%
"""
6]List down some best practices for exception handling in python.
answer]   

 1]       Always use specific exception instead of general exception.
 2]      Always print  proper messages
 3]      Always try to log our error
 4]      Do not write unnecessary multiple exception errors
 5]      Keep our code clean and structered
